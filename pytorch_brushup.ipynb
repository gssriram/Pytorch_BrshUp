# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import torch.nn.functional as F

# %%
df = pd.read_csv("./Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
cuda_availability = torch.cuda.is_available()
device = torch.device('cuda' if cuda_availability else 'cpu')

# %%
class iris(Dataset):
    def __init__(self, x, y) -> None:
        super().__init__()
        self.x = torch.tensor(x.values, dtype=torch.float32, device=device)
        self.y = torch.tensor(y.values.flatten(), dtype=torch.long, device=device)

    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, index):
        data = self.x[index]    
        label = self.y[index]
        return data, label

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df[['Species']], test_size=0.2, random_state=32)
train_data = iris(X_train, y_train)
test_data = iris(X_test, y_test)

# %%
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
class iris_model(nn.Module):
    def __init__(self, in_features, h1, out_features) -> None:
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)
        self.fc2 = nn.Linear(h1,out_features)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = iris_model(in_features=X_train.shape[1], h1=32, out_features=3)
model = model.to(device)
epoch = 100
criterion = nn.CrossEntropyLoss()
optimiser = torch.optim.Adam(model.parameters(), lr=1e-2)

for i in range(epoch):
    losses = 0
    for idx, data in enumerate(train_loader):
        epoch_loss = 0
        x, y = data
        optimiser.zero_grad()
        res = model(x)
        #print(res, y)
        loss = criterion(res, y)
        loss.backward()
        optimiser.step()
        losses += loss.item()
        epoch_loss += loss.item()

    #print(f'At epoch {i}, cumm. loss is {losses}')
    #print(f'At epoch {i}, current loss is {loss.item()}')
    print(f'At epoch {i}, current epoch loss is {epoch_loss}')
# Out:
# At epoch 0, current epoch loss is 1.2582753896713257
# At epoch 1, current epoch loss is 1.490930438041687
# At epoch 2, current epoch loss is 2.070891857147217
# At epoch 3, current epoch loss is 1.290015697479248
# At epoch 4, current epoch loss is 0.507476270198822
# At epoch 5, current epoch loss is 0.5929914712905884
# At epoch 6, current epoch loss is 0.7882558703422546
# At epoch 7, current epoch loss is 0.42484143376350403
# At epoch 8, current epoch loss is 0.5463254451751709
# At epoch 9, current epoch loss is 0.4394073188304901
# At epoch 10, current epoch loss is 0.4447683095932007
# At epoch 11, current epoch loss is 0.34763529896736145
# At epoch 12, current epoch loss is 0.5504084229469299
# At epoch 13, current epoch loss is 0.3152860105037689
# At epoch 14, current epoch loss is 0.2901690900325775
# At epoch 15, current epoch loss is 0.36539116501808167
# At epoch 16, current epoch loss is 0.3076247274875641
# At epoch 17, current epoch loss is 0.21601657569408417
# At epoch 18, current epoch loss is 0.2782709300518036
# At epoch 19, current epoch loss is 0.3544362783432007
# At epoch 20, current epoch loss is 0.25372520089149475
# At epoch 21, current epoch loss is 0.15296684205532074
# At epoch 22, current epoch loss is 0.16224506497383118
# At epoch 23, current epoch loss is 0.2301810383796692
# At epoch 24, current epoch loss is 0.2387859970331192
# At epoch 25, current epoch loss is 0.2064577341079712
# At epoch 26, current epoch loss is 0.3016648590564728
# At epoch 27, current epoch loss is 0.20456986129283905
# At epoch 28, current epoch loss is 0.1616773158311844
# At epoch 29, current epoch loss is 0.13810788094997406
# At epoch 30, current epoch loss is 0.14677943289279938
# At epoch 31, current epoch loss is 0.15483690798282623
# At epoch 32, current epoch loss is 0.19124279916286469
# At epoch 33, current epoch loss is 0.17641089856624603
# At epoch 34, current epoch loss is 0.15733948349952698
# At epoch 35, current epoch loss is 0.18707406520843506
# At epoch 36, current epoch loss is 0.3349341154098511
# At epoch 37, current epoch loss is 0.17516295611858368
# At epoch 38, current epoch loss is 0.21211709082126617
# At epoch 39, current epoch loss is 0.15838348865509033
# At epoch 40, current epoch loss is 0.1143273338675499
# At epoch 41, current epoch loss is 0.09490015357732773
# At epoch 42, current epoch loss is 0.1042381227016449
# At epoch 43, current epoch loss is 0.14895115792751312
# At epoch 44, current epoch loss is 0.1141163781285286
# At epoch 45, current epoch loss is 0.07015163451433182
# At epoch 46, current epoch loss is 0.13631270825862885
# At epoch 47, current epoch loss is 0.07610514760017395
# At epoch 48, current epoch loss is 0.05638721212744713
# At epoch 49, current epoch loss is 0.05337297543883324
# At epoch 50, current epoch loss is 0.09206338971853256
# At epoch 51, current epoch loss is 0.048139993101358414
# At epoch 52, current epoch loss is 0.09123421460390091
# At epoch 53, current epoch loss is 0.08092211931943893
# At epoch 54, current epoch loss is 0.13329502940177917
# At epoch 55, current epoch loss is 0.07182347774505615
# At epoch 56, current epoch loss is 0.07668734341859818
# At epoch 57, current epoch loss is 0.07948911190032959
# At epoch 58, current epoch loss is 0.04990832135081291
# At epoch 59, current epoch loss is 0.048236604779958725
# At epoch 60, current epoch loss is 0.05736251175403595
# At epoch 61, current epoch loss is 0.07869940996170044
# At epoch 62, current epoch loss is 0.08366023749113083
# At epoch 63, current epoch loss is 0.04997557774186134
# At epoch 64, current epoch loss is 0.05202836915850639
# At epoch 65, current epoch loss is 0.04112361744046211
# At epoch 66, current epoch loss is 0.07120423763990402
# At epoch 67, current epoch loss is 0.06023075804114342
# At epoch 68, current epoch loss is 0.03352212533354759
# At epoch 69, current epoch loss is 0.033496301621198654
# At epoch 70, current epoch loss is 0.04443621262907982
# At epoch 71, current epoch loss is 0.0495077483355999
# At epoch 72, current epoch loss is 0.03128230944275856
# At epoch 73, current epoch loss is 0.014811772853136063
# At epoch 74, current epoch loss is 0.14935223758220673
# At epoch 75, current epoch loss is 0.054257724434137344
# At epoch 76, current epoch loss is 0.05622018873691559
# At epoch 77, current epoch loss is 0.07053597271442413
# At epoch 78, current epoch loss is 0.15758369863033295
# At epoch 79, current epoch loss is 0.1351434290409088
# At epoch 80, current epoch loss is 0.14246773719787598
# At epoch 81, current epoch loss is 0.07250762730836868
# At epoch 82, current epoch loss is 0.03028015047311783
# At epoch 83, current epoch loss is 0.0683962032198906
# At epoch 84, current epoch loss is 0.016680216416716576
# At epoch 85, current epoch loss is 0.036300718784332275
# At epoch 86, current epoch loss is 0.03085784614086151
# At epoch 87, current epoch loss is 0.025101488456130028
# At epoch 88, current epoch loss is 0.07900536805391312
# At epoch 89, current epoch loss is 0.05232631787657738
# At epoch 90, current epoch loss is 0.020212529227137566
# At epoch 91, current epoch loss is 0.021035270765423775
# At epoch 92, current epoch loss is 0.0918659046292305
# At epoch 93, current epoch loss is 0.027693763375282288
# At epoch 94, current epoch loss is 0.05885421112179756
# At epoch 95, current epoch loss is 0.05877400562167168
# At epoch 96, current epoch loss is 0.021716991439461708
# At epoch 97, current epoch loss is 0.038970235735177994
# At epoch 98, current epoch loss is 0.027591630816459656
# At epoch 99, current epoch loss is 0.05326519533991814

# %%
from sklearn.metrics import accuracy_score

with torch.no_grad():
    res = []
    for idx, data in enumerate(test_loader):
        x, y = data
        output = model(x)
        _, pred = torch.max(output.data, 1)
        res = np.append(res, pred.cpu().detach().numpy())

accuracy_score(y_test, res)
# Out:
# 1.0
